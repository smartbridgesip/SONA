# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score

# %%
dataset = pd.read_csv(r'C:\Users\test01\Desktop\pp\1561873103203_data.csv')

# %%
dataset.isnull().any()
# Out:
# Make                 False
# Model                False
# Year                 False
# Engine Fuel Type     False
# Engine HP            False
# Engine Cylinders     False
# Transmission Type    False
# Driven_Wheels        False
# Number of Doors      False
# Market Category       True
# Vehicle Size         False
# Vehicle Style        False
# highway MPG          False
# city mpg             False
# Popularity           False
# MSRP                 False
# dtype: bool

# %%
dataset.fillna(dataset.mean(),inplace=True)

# %%
dataset.isnull().any()
# Out:
# Make                 False
# Model                False
# Year                 False
# Engine Fuel Type     False
# Engine HP            False
# Engine Cylinders     False
# Transmission Type    False
# Driven_Wheels        False
# Number of Doors      False
# Market Category       True
# Vehicle Size         False
# Vehicle Style        False
# highway MPG          False
# city mpg             False
# Popularity           False
# MSRP                 False
# dtype: bool

# %%
dataset[89:]
# Out:
#            Make                  Model  Year                Engine Fuel Type  \
# 89        Honda          Accord Hybrid  2014                regular unleaded
# 90        Honda          Accord Hybrid  2014                regular unleaded
# 91        Honda          Accord Hybrid  2014                regular unleaded
# 92        Honda          Accord Hybrid  2015                regular unleaded
# 93        Honda          Accord Hybrid  2015                regular unleaded
# 94        Honda          Accord Hybrid  2015                regular unleaded
# 95        Honda          Accord Hybrid  2017                regular unleaded
# 96        Honda          Accord Hybrid  2017                regular unleaded
# 97        Honda          Accord Hybrid  2017                regular unleaded
# 98        Honda  Accord Plug-In Hybrid  2014                regular unleaded
# 99        Honda                 Accord  2015                regular unleaded
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
dataset.corr()
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.060295         -0.459726        -0.287241
# Engine HP         0.060295   1.000000          0.716206         0.161987
# Engine Cylinders -0.459726   0.716206          1.000000         0.412001
# Number of Doors  -0.287241   0.161987          0.412001         1.000000
# highway MPG       0.436064  -0.562281         -0.691457        -0.128736
# city mpg          0.336868  -0.439498         -0.610391        -0.016046
# Popularity       -0.451839   0.470556          0.702545         0.455305
# MSRP              0.630846   0.646481          0.136152        -0.227446
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.436064  0.336868   -0.451839  0.630846
# Engine HP           -0.562281 -0.439498    0.470556  0.646481
# Engine Cylinders    -0.691457 -0.610391    0.702545  0.136152
# Number of Doors     -0.128736 -0.016046    0.455305 -0.227446
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset.drop("Year",axis=1,inplace=True)

# %%
dataset.drop("Vehicle Style",axis=1,inplace=True)

# %%
dataset.drop("Number of Doors",axis=1,inplace=True)

# %%
dataset.drop("Market Category",axis=1,inplace=True)

# %%
dataset.drop("Vehicle Size",axis=1,inplace=True)

# %%
dataset.drop("Model",axis=1,inplace=True)

# %%
dataset.drop("Engine HP",axis=1,inplace=True)

# %%
dataset.drop("Driven_Wheels",axis=1,inplace=True)

# %%
dataset.drop("city mpg",axis=1,inplace=True)

# %%
dataset.drop("Popularity",axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   Make             Engine Fuel Type  Engine Cylinders Transmission Type  \
# 0  BMW  premium unleaded (required)                 6            MANUAL
# 1  BMW  premium unleaded (required)                 6            MANUAL
# 2  BMW  premium unleaded (required)                 6            MANUAL
# 3  BMW  premium unleaded (required)                 6            MANUAL
# 4  BMW  premium unleaded (required)                 6            MANUAL
#
#    highway MPG   MSRP
# 0           26  46135
# 1           28  40650
# 2           28  36350
# 3           28  29450
# 4           28  34500

# %%
x=dataset.iloc[:,0:5].values

# %%
x
# Out:
# array([['BMW', 'premium unleaded (required)', 6, 'MANUAL', 26],
#        ['BMW', 'premium unleaded (required)', 6, 'MANUAL', 28],
#        ['BMW', 'premium unleaded (required)', 6, 'MANUAL', 28],
#        ...,
#        ['Volkswagen', 'regular unleaded', 4, 'AUTOMATIC', 34],
#        ['Volkswagen', 'regular unleaded', 4, 'AUTOMATIC', 34],
#        ['Volkswagen', 'regular unleaded', 4, 'AUTOMATIC', 34]],
#       dtype=object)

# %%
y=dataset.iloc[:,5:6].values

# %%
y
# Out:
# array([[46135],
#        [40650],
#        [36350],
#        [29450],
#        [34500],
#        [31200],
#        [44100],
#        [39300],
#        [36900],
#        [37200],
#        [39600],
#        [31500],
#        [44400],
#        [37200],
#        [31500],
#        [48250],
#        [43550],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [ 2000],
#        [27495],
#        [24995],
#        [28195],
#        [41365],
#        [35740],
#        [37615],
#        [34695],
#        [35725],
#        [43400],
#        [32820],
#        [38645],
#        [37825],
#        [43620],
#        [36115],
#        [35950],
#        [33210],
#        [38855],
#        [41585],
#        [35085],
#        [41310],
#        [36690],
#        [44360],
#        [39595],
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x[:,0]=lb.fit_transform(x[:,0])

# %%
lb2=LabelEncoder()
x[:,2]=lb2.fit_transform(x[:,2])

# %%
lb3=LabelEncoder()
x[:,3]=lb2.fit_transform(x[:,3])

# %%
lb4=LabelEncoder()
x[:,1]=lb2.fit_transform(x[:,1])

# %%
#lb5=LabelEncoder()
#x[:,4]=lb2.fit_transform(x[:,4])

# %%
x
# Out:
# array([[1, 2, 2, 2, 26],
#        [1, 2, 2, 2, 28],
#        [1, 2, 2, 2, 28],
#        ...,
#        [6, 3, 0, 1, 34],
#        [6, 3, 0, 1, 34],
#        [6, 3, 0, 1, 34]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
#oh=OneHotEncoder(categorical_features=[0])

# %%
#x=oh.fit_transform(x).toarray()

# %%
#x=x[:,1:]

# %%
lb.classes_[1]
# Out:
# 'BMW'

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
d=DecisionTreeRegressor(random_state=0)

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
y_pred=d.predict(x_test)

# %%
y_pred
# Out:
# array([27838.33333333, 30985.625     , 36033.33333333, 27838.33333333,
#        26318.33333333, 27111.        , 32966.25      , 30985.625     ,
#        37716.        , 24106.875     , 32966.25      , 45117.5       ,
#        26865.        , 29739.44444444,  2000.        , 16445.        ,
#        23450.71428571, 32088.33333333, 30985.625     , 23450.71428571,
#        32685.        , 27111.        , 32547.5       , 24106.875     ,
#        32685.        , 32547.5       , 27838.33333333, 23450.71428571,
#        30985.625     , 24094.        , 32088.33333333, 15251.25      ,
#        36033.33333333, 27111.        , 32685.        , 32895.        ,
#        30985.625     , 32685.        , 26318.33333333, 36033.33333333,
#        30985.625     , 32088.33333333, 33062.        , 26245.        ,
#        39455.55555556, 27221.        , 32966.25      , 16445.        ,
#        36033.33333333, 39455.55555556, 16445.        , 27615.        ,
# ...

# %%
y_test
# Out:
# array([[27475],
#        [33995],
#        [44400],
#        [27995],
#        [25490],
#        [26065],
#        [32670],
#        [29895],
#        [36690],
#        [25030],
#        [30890],
#        [48250],
#        [29395],
#        [31625],
#        [ 2000],
#        [17495],
#        [25885],
#        [29155],
#        [34950],
#        [23085],
#        [32595],
#        [26300],
#        [30745],
#        [24265],
#        [35095],
#        [33630],
#        [29595],
#        [23605],
#        [25995],
#        [26985],
#        [35055],
#        [16395],
#        [36900],
#        [26850],
#        [35975],
#        [34830],
#        [29395],
#        [31795],
#        [25975],
#        [31200],
#        [25450],
#        [31905],
#        [29670],
#        [28195],
#        [41850],
#        [24005],
#        [30890],
#        [16095],
#        [39300],
#        [36115],
#        [15745],
#        [24795],
#        [30095],
#        [32550],
#        [36915],
# ...

# %%
y_pred = d.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9038250439727069

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1871.5878637566134
# Mean Squared Error: 6058238.870677109
# Root Mean Squared Error: 2461.3489940837544

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r=RandomForestRegressor(n_estimators=10,random_state=0)

# %%
r.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred = r.predict(x_test)

# %%
y_test
# Out:
# array([[27475],
#        [33995],
#        [44400],
#        [27995],
#        [25490],
#        [26065],
#        [32670],
#        [29895],
#        [36690],
#        [25030],
#        [30890],
#        [48250],
#        [29395],
#        [31625],
#        [ 2000],
#        [17495],
#        [25885],
#        [29155],
#        [34950],
#        [23085],
#        [32595],
#        [26300],
#        [30745],
#        [24265],
#        [35095],
#        [33630],
#        [29595],
#        [23605],
#        [25995],
#        [26985],
#        [35055],
#        [16395],
#        [36900],
#        [26850],
#        [35975],
#        [34830],
#        [29395],
#        [31795],
#        [25975],
#        [31200],
#        [25450],
#        [31905],
#        [29670],
#        [28195],
#        [41850],
#        [24005],
#        [30890],
#        [16095],
#        [39300],
#        [36115],
#        [15745],
#        [24795],
#        [30095],
#        [32550],
#        [36915],
# ...

# %%
y_pred.shape
# Out:
# (60,)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8970281485424101

# %%
x_train.shape
# Out:
# (239, 5)
